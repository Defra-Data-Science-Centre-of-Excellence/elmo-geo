# %%
import pandas as pd

# %%
f = '~/shiny/MS8_Pesticides/data/pli_exports.xlsx'

# %%
df = pd.read_excel(f, sheet_name='Scores')

df
# Out:
#                              Name         chemgroup  Soil_DT50  Mobility  \
# 0           1-naphthylacetic acid  Growth regulator   4.864068  6.411625
# 1    2-chloroethylphosphonic acid  Growth regulator   1.860707  2.444822
# 2                           2,4-D         Herbicide   3.999733  6.671086
# 3                          2,4-DB         Herbicide   2.154299  2.740516
# 4                 6-benzyladenine  Growth regulator   0.127116  2.259547
# ..                            ...               ...        ...       ...
# 263              Trinexapac-ethyl  Growth regulator   2.014493  2.799035
# 264                 Triticonazole         Fungicide   9.085150  5.273755
# 265                          Urea         Fungicide   8.391021  2.590809
# 266             Zeta-cypermethrin       Insecticide   1.371387  1.927202
# 267                      Zoxamide         Fungicide   0.812164  2.455729
#
#      Drain_flow       BCF  Bird_LD50_short  Bird_NOEL_long  \
# ...
